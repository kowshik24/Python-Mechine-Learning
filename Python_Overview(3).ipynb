# %%
import pandas as pd

store_sales = pd.read_csv("store_sales.csv")
store_sales
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# ..      ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec
# 0     7    6
# 1    21   19
# 2    24    8
# ...

# %%
store_sales.dtypes
# Out:
# store_id    object
# city        object
# Jan          int64
# Feb          int64
# Mar          int64
# Apr          int64
# May          int64
# Jun          int64
# July         int64
# Aug          int64
# Sep          int64
# Oct          int64
# Nov          int64
# Dec          int64
# dtype: object

# %%
store_sales.groupby("city")["Jan"].agg("mean")
# Out:
# city
# Arizona       15.500000
# California    14.744186
# Texas         13.457143
# Name: Jan, dtype: float64

# %%
store_sales["Jan"].mean()
# Out:
# 14.46

# %% [markdown]
# # In case if the data-type of the column are not numerical then it shoud be indicate which of the datatype which may include in the calculation then we can simply wrote like this and another thing about the apply() function it will only work for the whole rows and columns like it is a generelised function
#
# N:B In many of older verion of pandas it may through an error but in the new verion it will not effect but it can be handy for us to be careful about our datatypes

# %%
store_sales.select_dtypes(include=['int64','float64']).apply("mean")
# Out:
# Jan     14.46
# Feb     15.09
# Mar     14.56
# Apr     14.57
# May     13.56
# Jun     13.80
# July    14.38
# Aug     15.81
# Sep     14.91
# Oct     14.10
# Nov     15.31
# Dec     13.57
# dtype: float64

# %%
store_sales.apply("mean",axis = 0)
# Out:
# Jan     14.46
# Feb     15.09
# Mar     14.56
# Apr     14.57
# May     13.56
# Jun     13.80
# July    14.38
# Aug     15.81
# Sep     14.91
# Oct     14.10
# Nov     15.31
# Dec     13.57
# dtype: float64

# %% [markdown]
# # axis = 1; then it will work for horizontally but if axis = 0 or nothing will given then it will work on vertically by default

# %%
store_sales.apply("mean" ,axis = 1)
# Out:
# 0     14.833333
# 1     14.500000
# 2     15.083333
# 3     11.250000
# 4     13.250000
#         ...
# 95    15.416667
# 96    12.833333
# 97    14.000000
# 98    14.416667
# 99    15.000000
# Length: 100, dtype: float64

# %%
def add(a,b):
    res = a+b;
    return res


add(3,4)
# Out:
# 7

# %%
sales = store_sales.groupby("city")["Jan","Feb","Mar","Apr","May","Jun", "July", "Aug","Sep","Oct","Nov","Dec"].agg(["mean","max","min","sum"])
sales.reset_index(inplace=True)
sales.head()
# Out:
#          city        Jan                     Feb                     Mar  ...  \
#                     mean max min  sum       mean max min  sum       mean  ...
# 0     Arizona  15.500000  23   7  341  15.272727  24   6  336  14.545455  ...
# 1  California  14.744186  24   5  634  15.534884  24   5  668  14.627907  ...
# 2       Texas  13.457143  24   5  471  14.428571  24   5  505  14.485714  ...
#
#   Oct             Nov                     Dec
#   min  sum       mean max min  sum       mean max min  sum
# 0   5  329  16.409091  24   5  361  13.318182  24   5  293
# 1   5  614  15.279070  24   5  657  13.604651  24   5  585
# 2   5  467  14.657143  24   6  513  13.685714  24   5  479
#
# [3 rows x 49 columns]

# %%
def bonus_func(sales_number):
    return ["Elegible" if x>15 else "Not Eligible" for x in sales_number]

sales_number = [12,23,3,2,3,123,123]

bonus_func(sales_number)
# Out:
# ['Not Eligible',
#  'Elegible',
#  'Not Eligible',
#  'Not Eligible',
#  'Not Eligible',
#  'Elegible',
#  'Elegible']

# %% [markdown]
# # If the Jan sales is > 10 then it will be eligible for bonous otherwise not

# %%
import numpy as np

def bouns_func(sales_col):
    elig_values = np.where(sales_col>10 , "Eligile" , "Not Eligible")
    return elig_values


store_sales["Jan_bonus"] = bonus_func(store_sales["Jan"])

store_sales
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# ..      ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec     Jan_bonus
# 0     7    6  Not Eligible
# ...

# %%
import numpy as np

def bouns_func(sales_col):
    elig_values = np.where(sales_col>10 , "Eligile" , "Not Eligible")
    return elig_values


#store_sales["Jan_bonus"] = bonus_func(store_sales["Jan"])
newdf = store_sales.select_dtypes(include=['int64','float64']).apply(bonus_func)
#newdf

kowshik = pd.concat([store_sales,newdf],axis = 1)
kowshik.shape
kowshik["Jan"]
# Out:
#    Jan           Jan
# 0    8  Not Eligible
# 1   12  Not Eligible
# 2   16      Elegible
# 3    8  Not Eligible
# 4   19      Elegible
# ..  ..           ...
# 95   7  Not Eligible
# 96  13  Not Eligible
# 97  16      Elegible
# 98  18      Elegible
# 99   5  Not Eligible
#
# [100 rows x 2 columns]

# %%
import pandas as pd

auto_mobile = pd.read_csv("Automobile_Data.csv")
auto_mobile
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
auto_mobile.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...
